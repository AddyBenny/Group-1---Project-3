# %%
#import Dependencies
from splinter import Browser
from bs4 import BeautifulSoup
import pandas as pd
import pymongo 
import requests
from config import api_key

# %%
# #executable path for window users
# executable_path = {'executable_path': 'chromedriver.exe'}
# browser = Browser('chrome', **executable_path, headless=False)

# %%
#Initialize pymongo to work with MongoDBs
#CONNECT MONGO DB
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Executable path for Mac Users
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
#url of page to be scraped from indeed
url = 'https://www.indeed.com/jobs?q=Software+Engineer&l=Irvine%2C+CA&radius=100'
browser.visit(url)

# %%
#BeautifulSoup object Parser
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
#result to return the job title
titles = soup.find_all("h2", class_ = "title")
print(titles)
#title[1].get_text()
# Out:
# [<h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0DSJVOgFNjTH3NHsz1y5W7iEiQ8XFPauIDjgJYsd-OdNLeg3X3B2bDiJFBMXKrgB8Cc3lh2uHFnxwFa3_G81uJq8h0YPsu1bqktj9WwY8gX8ghU6g2YHgticn1Z9tA2oy4mIx5BC5HjhypjwhLn92E6PsRN5qwF-IqablSFGNvWbF2N1vFf2VZtVxsaClyFpOEoinmJ9zyvypimeSPv9qNcgsW92jxuh0wdoVcpusk7EaxVv0-yCVXbK9UjeXH5-_3Otlrd_dUQhElOCK_SIl6Ba3lXzjCP46M153Pahzu1LNUEsBZ5Vv40wSLjp680IQB7nav81FxzN_5vD07FpY9sSbNo-W1vU911hKwjYEhHal7GuS2UfgWGwim_Rih4g_U0QZ0TbZOPcJTLUGxsDSXGMAhXAKEYPd6YFE3nkGaopvyfLy-VObQ_LICUzKEXXCB7y_MEeRaWXC_v9HfQ_LgO&amp;p=0&amp;fvj=1&amp;vjs=3" id="sja0" onclick="setRefineByCookie(['radius']); sjoc('sja0', 1); convCtr('SJ'); rclk(this,jobmap[0],true,1);" onmousedown="sjomd('sja0'); clk('sja0'); rclk(this,jobmap[0],1);" rel="noopener nofollow" target="_blank" title="Software Engineer">
# <b>Software</b> <b>Engineer</b></a>
# </h2>, <h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=c0abe15389779068&amp;fccid=11299cf8233dcb1c&amp;vjs=3" id="jl_c0abe15389779068" onclick="setRefineByCookie(['radius']); return rclk(this,jobmap[1],true,0);" onmousedown="return rclk(this,jobmap[1],0);" rel="noopener nofollow" target="_blank" title="Software Engineer">
# <b>Software</b> <b>Engineer</b></a>
# </h2>, <h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=ac8c8e4cd7932e29&amp;fccid=1639254ea84748b5&amp;vjs=3" id="jl_ac8c8e4cd7932e29" onclick="setRefineByCookie(['radius']); return rclk(this,jobmap[2],true,0);" onmousedown="return rclk(this,jobmap[2],0);" rel="noopener nofollow" target="_blank" title="Software Engineer, University Grad">
# <b>Software</b> <b>Engineer</b>, University Grad</a>
# <span class="new">new</span></h2>, <h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0AMr11YIOo206dX9CE572HoIBzjTozchv3QrfVeNVhstmAbPwFeZPDdQ1m4GCFFknpqTVA8J_imAJVUTpPXQ5pP4QoSYeZlex-6sqyWjV7NE_850u0UChpfUKrJJ-LtLUrozQz0zOMF_ONNqrFE05qiNGdXLCovB9lgNi2veACllY2clWaVTA6J8T_RrThykRvH5qSwdaQD9bKFz9_So2ns35UI-vZn-DKeK6r4DYqFXxSrK1nXbaf9uyidLpDnWgAWskNcn581hUVRF0QN-O6TnbuPNfbsjX21nXKxLTzT1MME2pgvhK_k1Y0cALd4pQQZieTHilrHB0QtZ_T2UF1rbKPi7H5_QP4RM5sWxdeAf82sPwcnLSN3dzJ_zzi9Em7sxYL_ym7y_GKfULEQ6I5Qu3kM7o6cjbcs1uQ6TMmCgQyQc-K749HHmAmztxmobEMdf3Gn9bfYkp2DIBscZY6DqmOGelJ5-JS2UP0h-rvShpTulIJY0rEa9_0pttEt3puFfclYguCebw==&amp;p=3&amp;fvj=1&amp;vjs=3" id="sja3" onclick="setRefineByCookie(['radius']); sjoc('sja3', 1); convCtr('SJ'); rclk(this,jobmap[3],true,1);" onmousedown="sjomd('sja3'); clk('sja3'); rclk(this,jobmap[3],1);" rel="noopener nofollow" target="_blank" title="Software Engineer">
# <b>Software</b> <b>Engineer</b></a>
# <span class="new">new</span></h2>, <h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=194a7880a5ff9314&amp;fccid=30cc7a5451d4ee77&amp;vjs=3" id="jl_194a7880a5ff9314" onclick="setRefineByCookie(['radius']); return rclk(this,jobmap[4],true,0);" onmousedown="return rclk(this,jobmap[4],0);" rel="noopener nofollow" target="_blank" title="Jr Full Stack Software Engineer">
# Jr Full Stack <b>Software</b> <b>Engineer</b></a>
# </h2>, <h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=a000c399cdd83f72&amp;fccid=749488582f5dfbfe&amp;vjs=3" id="jl_a000c399cdd83f72" onclick="setRefineByCookie(['radius']); return rclk(this,jobmap[5],true,0);" onmousedown="return rclk(this,jobmap[5],0);" rel="noopener nofollow" target="_blank" title="Software Engineer- Entry Level">
# <b>Software</b> <b>Engineer</b>- Entry Level</a>
# </h2>, <h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0AiQ2Ue3759HkB1rZXapRUZoTtrV-x-3oUi90yO91Ofc8yBhywOoo1XtpOcsISueATABZNxo5cYUYcAwW24X6DxWIqHQp7fdILC3fwXNJ2nUGKL6u0Hqpq2TMDzGDy8zEw_2OK83UWnfidS9Ya2PAE-cpH_2nP0mGjv2rsZUW-XafRpewD73lKyXSYaM2q8CL-6L2MQSdJrir3ObS0ioFFmKE3SAy14tg3xigy2RS-mj7_BsAbLCE4wJXD4Z2cJEgctgCmDwbVNYjbFu7HhCp9KuibF8u47l4nKFN9xrjaRXu1zsKCthx-ARVJhLHkFCM4ESsp6-c8qQ2hQLmVXLQ9YOJ5xsCg8zvKziLTMgEulRsTRZLgHXIVzOOfiERBCXZoDwA2gJx0hYnwcSYFxEPz8pDBdZw_hZsQxxMHNmsFakmqWepxQycBgvlFjisz3mnsBowacp1JW0JqyWVoexzbQ&amp;p=6&amp;fvj=1&amp;vjs=3" id="sja6" onclick="setRefineByCookie(['radius']); sjoc('sja6', 1); convCtr('SJ'); rclk(this,jobmap[6],true,1);" onmousedown="sjomd('sja6'); clk('sja6'); rclk(this,jobmap[6],1);" rel="noopener nofollow" target="_blank" title="Software Developer">
# <b>Software</b> Developer</a>
# </h2>, <h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/company/AYANA-Therapy/jobs/Junior-Software-Engineer-ba5ac99bfc468d59?fccid=67241bb681f973a3&amp;vjs=3" id="jl_ba5ac99bfc468d59" onclick="setRefineByCookie(['radius']); return rclk(this,jobmap[7],true,1);" onmousedown="return rclk(this,jobmap[7],1);" rel="noopener nofollow" target="_blank" title="Junior Software Engineer">
# Junior <b>Software</b> <b>Engineer</b></a>
# <span class="new">new</span></h2>, <h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=d1ab272b9e0d0c6e&amp;fccid=f368300325e8e8bc&amp;vjs=3" id="jl_d1ab272b9e0d0c6e" onclick="setRefineByCookie(['radius']); return rclk(this,jobmap[8],true,0);" onmousedown="return rclk(this,jobmap[8],0);" rel="noopener nofollow" target="_blank" title="Software Engineer, Backend 1+ Years Experience - Los Angeles">
# <b>Software</b> <b>Engineer</b>, Backend 1+ Years Experience - Los Angeles</a>
# </h2>, <h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=6d898cf51ecbbe7a&amp;fccid=7942658690eba67c&amp;vjs=3" id="jl_6d898cf51ecbbe7a" onclick="setRefineByCookie(['radius']); return rclk(this,jobmap[9],true,0);" onmousedown="return rclk(this,jobmap[9],0);" rel="noopener nofollow" target="_blank" title="Software Engineer I">
# <b>Software</b> <b>Engineer</b> I</a>
# <span class="new">new</span></h2>, <h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/company/Intellivision-Entertainment/jobs/Software-Engineer-Game-Control-System-Prototyping-08e8cf404cfab3e6?fccid=a1008821fc77a187&amp;vjs=3" id="jl_08e8cf404cfab3e6" onclick="setRefineByCookie(['radius']); return rclk(this,jobmap[10],true,1);" onmousedown="return rclk(this,jobmap[10],1);" rel="noopener nofollow" target="_blank" title="Software Engineer for Game Control Systems and Prototyping">
# <b>Software</b> <b>Engineer</b> for Game Control Systems and Prototyping</a>
# <span class="new">new</span></h2>, <h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=5637a802ed64c77e&amp;fccid=fe2d21eef233e94a&amp;vjs=3" id="jl_5637a802ed64c77e" onclick="setRefineByCookie(['radius']); return rclk(this,jobmap[11],true,0);" onmousedown="return rclk(this,jobmap[11],0);" rel="noopener nofollow" target="_blank" title="Software Development Engineer">
# <b>Software</b> Development <b>Engineer</b></a>
# <span class="new">new</span></h2>, <h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=6a8c586ac5ab0288&amp;fccid=ee6807b900a9998d&amp;vjs=3" id="jl_6a8c586ac5ab0288" onclick="setRefineByCookie(['radius']); return rclk(this,jobmap[12],true,0);" onmousedown="return rclk(this,jobmap[12],0);" rel="noopener nofollow" target="_blank" title="Software Engineer">
# <b>Software</b> <b>Engineer</b></a>
# </h2>, <h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=a5584656a86226c5&amp;fccid=d278789782e164b3&amp;vjs=3" id="jl_a5584656a86226c5" onclick="setRefineByCookie(['radius']); return rclk(this,jobmap[13],true,1);" onmousedown="return rclk(this,jobmap[13],1);" rel="noopener nofollow" target="_blank" title="Software Developer">
# <b>Software</b> Developer</a>
# </h2>, <h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=121f1fa37c14de5e&amp;fccid=535f108e774016a4&amp;vjs=3" id="jl_121f1fa37c14de5e" onclick="setRefineByCookie(['radius']); return rclk(this,jobmap[14],true,0);" onmousedown="return rclk(this,jobmap[14],0);" rel="noopener nofollow" target="_blank" title="Entry Level Software Engineer">
# Entry Level <b>Software</b> <b>Engineer</b></a>
# </h2>]

# %%
#result to be Returned as an iterable list
for title in titles:
    job_title = title.get_text()
    print(job_title)
# Out:
# Software Engineer
#
#
#
# Software Engineer
#
#
#
# Software Engineer, University Grad
# new
#
#
# Software Engineer
# new
#
#
# Jr Full Stack Software Engineer
#
#
#
# Software Engineer- Entry Level
#
#
#
# Software Developer
#
#
#
# Junior Software Engineer
# new
#
#
# Software Engineer, Backend 1+ Years Experience - Los Angeles
#
#
#
# Software Engineer I
# new
#
#
# Software Engineer for Game Control Systems and Prototyping
# new
#
#
# Software Development Engineer
# new
#
#
# Software Engineer
#
#
#
# Software Developer
#
#
#
# Entry Level Software Engineer

# %%
try:
    dismiss = browser.find_by_xpath('/html/body/div[2]/div/section/div/div[2]')
    more_jobs = browser.find_by_xpath('/html/body/table[2]/tbody/tr/td/table/tbody/tr/td[1]/nav/div/ul/li[6]/a/span')
    no_thanks = browser.find_by_xpath('/html/body/div[3]/div[2]/div[4]/div[3]/div[2]/a')
    dismiss.first.click()
    more_jobs.first.click()
    no_thanks.first.click()
except:
    print("not found")
# Out:
# not found

# %%
#Empty list to append the the result and index 0 is an int 
job_titles = [0]
 #loop through the result
for x in range(1, 2):
    titles = soup.find_all("h2", class_ = "title")
    for title in titles:
        job_titles.append(title.text)
        print('page:', x, '-------------')
        print(title.text)
        browser.find_by_xpath('/html/body/table[2]/tbody/tr/td/table/tbody/tr/td[1]/nav/div/ul/li[6]/a/span/span')
# Out:
# page: 1 -------------
#
#
# Software Engineer
#
# page: 1 -------------
#
#
# Software Engineer
#
# page: 1 -------------
#
#
# Software Engineer, University Grad
# new
# page: 1 -------------
#
#
# Software Engineer
# new
# page: 1 -------------
#
#
# Jr Full Stack Software Engineer
#
# page: 1 -------------
#
#
# Software Engineer- Entry Level
#
# page: 1 -------------
#
#
# Software Developer
#
# page: 1 -------------
#
#
# Junior Software Engineer
# new
# page: 1 -------------
#
#
# Software Engineer, Backend 1+ Years Experience - Los Angeles
#
# page: 1 -------------
#
#
# Software Engineer I
# new
# page: 1 -------------
#
#
# Software Engineer for Game Control Systems and Prototyping
# new
# page: 1 -------------
#
#
# Software Development Engineer
# new
# page: 1 -------------
#
#
# Software Engineer
#
# page: 1 -------------
#
#
# Software Developer
#
# page: 1 -------------
#
#
# Entry Level Software Engineer

# %%
#Use replace to print out a clean job title
clean_job_titles = []

#loop through the result
for job in job_titles[1:]:
    clean_job_title = job.replace('\n', '')
    clean_job_titles.append(clean_job_title)

# %%
#print clean job titles to check
print(clean_job_titles)
# Out:
# ['Software Engineer', 'Software Engineer', 'Software Engineer, University Gradnew', 'Software Engineernew', 'Jr Full Stack Software Engineer', 'Software Engineer- Entry Level', 'Software Developer', 'Junior Software Engineernew', 'Software Engineer, Backend 1+ Years Experience - Los Angeles', 'Software Engineer Inew', 'Software Engineer for Game Control Systems and Prototypingnew', 'Software Development Engineernew', 'Software Engineer', 'Software Developer', 'Entry Level Software Engineer']

# %%
#result to return the job locations
locations = soup.find_all("span", class_ = "location accessible-contrast-color-location")
locations
# Out:
# [<span class="location accessible-contrast-color-location">Irvine, CA</span>,
#  <span class="location accessible-contrast-color-location">Los Angeles, CA</span>,
#  <span class="location accessible-contrast-color-location">Burbank, CA</span>,
#  <span class="location accessible-contrast-color-location">Irvine, CA</span>,
#  <span class="location accessible-contrast-color-location">Los Angeles, CA 90071 <span style="font-size: smaller">(Downtown area)</span></span>,
#  <span class="location accessible-contrast-color-location">Los Angeles, CA 90291 <span style="font-size: smaller">(Venice area)</span></span>,
#  <span class="location accessible-contrast-color-location">Sylmar, CA</span>,
#  <span class="location accessible-contrast-color-location">Irvine, CA 92614 <span style="font-size: smaller">(Business District area)</span></span>,
#  <span class="location accessible-contrast-color-location">Irvine, CA</span>,
#  <span class="location accessible-contrast-color-location">Irvine, CA</span>,
#  <span class="location accessible-contrast-color-location">Newport Beach, CA 92660</span>,
#  <span class="location accessible-contrast-color-location">Buena Park, CA 90620</span>]

# %%
#Empty list to append the result
job_locations = []

#loop through the returned result
for x in range(1, 2):
    locations = soup.find_all("span", class_ = "location accessible-contrast-color-location")
    for location in locations:
        job_locations.append(location.text)
        print('page:', x, '-------------')
        print(location.text)
        browser.find_by_xpath('/html/body/table[2]/tbody/tr/td/table/tbody/tr/td[1]/div[7]/div[1]/span[1]')
# Out:
# page: 1 -------------
# Irvine, CA
# page: 1 -------------
# Los Angeles, CA
# page: 1 -------------
# Burbank, CA
# page: 1 -------------
# Irvine, CA
# page: 1 -------------
# Los Angeles, CA 90071 (Downtown area)
# page: 1 -------------
# Los Angeles, CA 90291 (Venice area)
# page: 1 -------------
# Sylmar, CA
# page: 1 -------------
# Irvine, CA 92614 (Business District area)
# page: 1 -------------
# Irvine, CA
# page: 1 -------------
# Irvine, CA
# page: 1 -------------
# Newport Beach, CA 92660
# page: 1 -------------
# Buena Park, CA 90620

# %%
#print job locations
print(job_locations)
# Out:
# ['Irvine, CA', 'Los Angeles, CA', 'Burbank, CA', 'Irvine, CA', 'Los Angeles, CA 90071 (Downtown area)', 'Los Angeles, CA 90291 (Venice area)', 'Sylmar, CA', 'Irvine, CA 92614 (Business District area)', 'Irvine, CA', 'Irvine, CA', 'Newport Beach, CA 92660', 'Buena Park, CA 90620']

# %%
#zip both results into a list
new_list = list(zip(clean_job_titles, job_locations))

# %%
#print new_list that has both the job_titiles and locations
print(new_list)
# Out:
# [('Software Engineer', 'Irvine, CA'), ('Software Engineer', 'Los Angeles, CA'), ('Software Engineer, University Gradnew', 'Burbank, CA'), ('Software Engineernew', 'Irvine, CA'), ('Jr Full Stack Software Engineer', 'Los Angeles, CA 90071 (Downtown area)'), ('Software Engineer- Entry Level', 'Los Angeles, CA 90291 (Venice area)'), ('Software Developer', 'Sylmar, CA'), ('Junior Software Engineernew', 'Irvine, CA 92614 (Business District area)'), ('Software Engineer, Backend 1+ Years Experience - Los Angeles', 'Irvine, CA'), ('Software Engineer Inew', 'Irvine, CA'), ('Software Engineer for Game Control Systems and Prototypingnew', 'Newport Beach, CA 92660'), ('Software Development Engineernew', 'Buena Park, CA 90620')]

# %%
#append list into a python dictionary
updated_list = dict(new_list)
updated_list
# Out:
# {'Software Engineer': 'Los Angeles, CA',
#  'Software Engineer, University Gradnew': 'Burbank, CA',
#  'Software Engineernew': 'Irvine, CA',
#  'Jr Full Stack Software Engineer': 'Los Angeles, CA 90071 (Downtown area)',
#  'Software Engineer- Entry Level': 'Los Angeles, CA 90291 (Venice area)',
#  'Software Developer': 'Sylmar, CA',
#  'Junior Software Engineernew': 'Irvine, CA 92614 (Business District area)',
#  'Software Engineer, Backend 1+ Years Experience - Los Angeles': 'Irvine, CA',
#  'Software Engineer Inew': 'Irvine, CA',
#  'Software Engineer for Game Control Systems and Prototypingnew': 'Newport Beach, CA 92660',
#  'Software Development Engineernew': 'Buena Park, CA 90620'}

# %%
#append colums keys
New_job_location_df = pd.DataFrame(new_list, columns=['Job_Title', 'Location'])
New_job_location_df
# Out:
#                                             Job_Title  \
# 0                                   Software Engineer
# 1                                   Software Engineer
# 2               Software Engineer, University Gradnew
# 3                                Software Engineernew
# 4                     Jr Full Stack Software Engineer
# 5                      Software Engineer- Entry Level
# 6                                  Software Developer
# 7                         Junior Software Engineernew
# 8   Software Engineer, Backend 1+ Years Experience...
# 9                              Software Engineer Inew
# 10  Software Engineer for Game Control Systems and...
# 11                   Software Development Engineernew
#
#                                      Location
# 0                                  Irvine, CA
# 1                             Los Angeles, CA
# 2                                 Burbank, CA
# 3                                  Irvine, CA
# 4       Los Angeles, CA 90071 (Downtown area)
# 5         Los Angeles, CA 90291 (Venice area)
# 6                                  Sylmar, CA
# 7   Irvine, CA 92614 (Business District area)
# 8                                  Irvine, CA
# 9                                  Irvine, CA
# 10                    Newport Beach, CA 92660
# 11                       Buena Park, CA 90620

# %%
New_job_location_df['City'] = New_job_location_df['Location'].str.split(',').str[0]

# %%
New_job_location_df['Lat'] = ''
New_job_location_df['Lng'] = ''

# %%
New_job_location_df
# Out:
#                                             Job_Title  \
# 0                                   Software Engineer
# 1                                   Software Engineer
# 2               Software Engineer, University Gradnew
# 3                                Software Engineernew
# 4                     Jr Full Stack Software Engineer
# 5                      Software Engineer- Entry Level
# 6                                  Software Developer
# 7                         Junior Software Engineernew
# 8   Software Engineer, Backend 1+ Years Experience...
# 9                              Software Engineer Inew
# 10  Software Engineer for Game Control Systems and...
# 11                   Software Development Engineernew
#
#                                      Location           City Lat Lng
# 0                                  Irvine, CA         Irvine
# 1                             Los Angeles, CA    Los Angeles
# 2                                 Burbank, CA        Burbank
# 3                                  Irvine, CA         Irvine
# 4       Los Angeles, CA 90071 (Downtown area)    Los Angeles
# 5         Los Angeles, CA 90291 (Venice area)    Los Angeles
# 6                                  Sylmar, CA         Sylmar
# 7   Irvine, CA 92614 (Business District area)         Irvine
# 8                                  Irvine, CA         Irvine
# 9                                  Irvine, CA         Irvine
# 10                    Newport Beach, CA 92660  Newport Beach
# 11                       Buena Park, CA 90620     Buena Park

# %%
for index, row in New_job_location_df.iterrows():
    city = row['City']
    base_url = "https://api.mapbox.com/geocoding/v5/mapbox.places/"
    response = requests.get(f'{base_url}{city}.json?access_token={api_key}').json()
    
    try:
        print(f'Retrieving rating data for {city}')
        New_job_location_df.loc[index, 'Lat'] = response['features'][0]['geometry']['coordinates'][1]
        New_job_location_df.loc[index, 'Lng'] = response['features'][0]['geometry']['coordinates'][0]
    except(KeyError, IndexError):
        print('Missing data')
# Out:
# Retrieving rating data for Irvine
# Retrieving rating data for Los Angeles
# Retrieving rating data for Burbank
# Retrieving rating data for Irvine
# Retrieving rating data for Los Angeles
# Retrieving rating data for Los Angeles
# Retrieving rating data for Sylmar
# Retrieving rating data for Irvine
# Retrieving rating data for Irvine
# Retrieving rating data for Irvine
# Retrieving rating data for Newport Beach
# Retrieving rating data for Buena Park

# %%
New_job_location_df
# Out:
#                                             Job_Title  \
# 0                                   Software Engineer
# 1                                   Software Engineer
# 2               Software Engineer, University Gradnew
# 3                                Software Engineernew
# 4                     Jr Full Stack Software Engineer
# 5                      Software Engineer- Entry Level
# 6                                  Software Developer
# 7                         Junior Software Engineernew
# 8   Software Engineer, Backend 1+ Years Experience...
# 9                              Software Engineer Inew
# 10  Software Engineer for Game Control Systems and...
# 11                   Software Development Engineernew
#
#                                      Location           City      Lat      Lng
# 0                                  Irvine, CA         Irvine  33.6857 -117.826
# 1                             Los Angeles, CA    Los Angeles  34.0544 -118.244
# 2                                 Burbank, CA        Burbank  34.1816 -118.326
# 3                                  Irvine, CA         Irvine  33.6857 -117.826
# 4       Los Angeles, CA 90071 (Downtown area)    Los Angeles  34.0544 -118.244
# 5         Los Angeles, CA 90291 (Venice area)    Los Angeles  34.0544 -118.244
# 6                                  Sylmar, CA         Sylmar  34.3076 -118.449
# 7   Irvine, CA 92614 (Business District area)         Irvine  33.6857 -117.826
# 8                                  Irvine, CA         Irvine  33.6857 -117.826
# 9                                  Irvine, CA         Irvine  33.6857 -117.826
# 10                    Newport Beach, CA 92660  Newport Beach   33.617 -117.929
# 11                       Buena Park, CA 90620     Buena Park  33.8704 -117.996

# %%
# test_city = 'Irvine'
# base_url = "https://api.mapbox.com/geocoding/v5/mapbox.places/"
# search = base_url + test_city + '.json?access_token=' + api_key

# response = requests.get(search).json()
# response


# lat = response['features'][0]['geometry']['coordinates'][1]
# lng = response['features'][0]['geometry']['coordinates'][0]
# print(lat)
# print(lng)

# %%
New_job_location_df['job_type'] = 'Sowftware Engineer'

# %%
New_job_location_df
# Out:
#                                             Job_Title  \
# 0                                   Software Engineer
# 1                                   Software Engineer
# 2               Software Engineer, University Gradnew
# 3                                Software Engineernew
# 4                     Jr Full Stack Software Engineer
# 5                      Software Engineer- Entry Level
# 6                                  Software Developer
# 7                         Junior Software Engineernew
# 8   Software Engineer, Backend 1+ Years Experience...
# 9                              Software Engineer Inew
# 10  Software Engineer for Game Control Systems and...
# 11                   Software Development Engineernew
#
#                                      Location           City      Lat  \
# 0                                  Irvine, CA         Irvine  33.6857
# 1                             Los Angeles, CA    Los Angeles  34.0544
# 2                                 Burbank, CA        Burbank  34.1816
# 3                                  Irvine, CA         Irvine  33.6857
# 4       Los Angeles, CA 90071 (Downtown area)    Los Angeles  34.0544
# 5         Los Angeles, CA 90291 (Venice area)    Los Angeles  34.0544
# 6                                  Sylmar, CA         Sylmar  34.3076
# 7   Irvine, CA 92614 (Business District area)         Irvine  33.6857
# 8                                  Irvine, CA         Irvine  33.6857
# 9                                  Irvine, CA         Irvine  33.6857
# 10                    Newport Beach, CA 92660  Newport Beach   33.617
# 11                       Buena Park, CA 90620     Buena Park  33.8704
#
#         Lng            job_type
# 0  -117.826  Sowftware Engineer
# 1  -118.244  Sowftware Engineer
# 2  -118.326  Sowftware Engineer
# 3  -117.826  Sowftware Engineer
# 4  -118.244  Sowftware Engineer
# 5  -118.244  Sowftware Engineer
# 6  -118.449  Sowftware Engineer
# 7  -117.826  Sowftware Engineer
# 8  -117.826  Sowftware Engineer
# 9  -117.826  Sowftware Engineer
# 10 -117.929  Sowftware Engineer
# 11 -117.996  Sowftware Engineer

# %%
#Define database and collection
#Database = Indeed_db
#Collections = Software_jobs
client.Indeed_db.Data_jobs.insert_many(New_job_location_df.to_dict('records'))

# %%
#Done
