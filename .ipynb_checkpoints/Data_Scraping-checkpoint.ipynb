# %%
#import Dependencies
from splinter import Browser
from bs4 import BeautifulSoup
import pandas as pd
import pymongo 
import requests
from config import api_key

# %%
# #executable path for window users
# executable_path = {'executable_path': 'chromedriver.exe'}
# browser = Browser('chrome', **executable_path, headless=False)

# %%
#Initialize pymongo to work with MongoDBs
#CONNECT MONGO DB
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Executable path for Mac Users
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
#url of page to be scrapped from indeed 
url = 'https://www.indeed.com/jobs?q=Data+Scientist&l=Irvine%2C+CA&radius=100'
browser.visit(url)

# %%
#BeautifulSoup Parser
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
#result to return the job title
titles = soup.find_all("h2", class_ = "title")
print(titles)
#title[1].get_text()
# Out:
# [<h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0AnQhcI30S35noZYX7fptC9JHDBVuSQzNzWdPUWRF9nG_TgfFeJcuyvoA_Dmg8a2SWU0CWz29S6MT30H2yhzzsBpPN9y0B6egimIjGTLXX1oUyXsUX7-ksrT2fHw1ZxE675VWanqeqU3t9LUAatd_nATymTC1UVJ8jmJ9jwNZRqU62Fs0b50ecCtTfvLY9p7TW29Rl2CKXw3nmjQo_1-VoO2eeba95p8_2_Ld1Lx04g3eh_MmR3hD1YCSwK_w1RexU2P5URinkm-Z3t715PSaCcoZ6n9Te5JAgOhrz4PvGSOYiYtRRIG1BH93JCJ3GgkZv7m_UWgKS5Lcku3YpEWVIE9Pr-biPegnRx4KsYzmxeAiC_U__xML8Qwk-BF8qzgecU9-HpA1ooSnbY1zywXuxscE_3GmpFYxW6rAioy9_N6FFfvTHrLBiQGiJOUaEU1CyFfiPw_QW9x0QDnqWa1Nue&amp;p=0&amp;fvj=1&amp;vjs=3" id="sja0" onclick="setRefineByCookie(['radius']); sjoc('sja0', 1); convCtr('SJ'); rclk(this,jobmap[0],true,1);" onmousedown="sjomd('sja0'); clk('sja0'); rclk(this,jobmap[0],1);" rel="noopener nofollow" target="_blank" title="Educational Data Scientist">
# Educational <b>Data</b> <b>Scientist</b></a>
# </h2>, <h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0AMr11YIOo206dX9CE572HoIBzjTozchv3QrfVeNVhstmAbPwFeZPDdH5w4MW3uUm59zxvwZmewuUare5btROGxqWx-_fSqJeoXHzgLaa8yIT3c-7Q_Qgpv8mTModHRHthZsuQggKKJ9TnHriBpY7kvmeTBHlvkjXeCuKGqTWnOLk1Ejk3aguHuIdDOdbGuaPFGIB0sL4hR1onXQpJMs5mFaca-h69XnqEZS_SdyKYRW4UV7swwgML8WafqxZcMJc28mZsOmW4gn6iKGtczl2FCRKM9-hrS_orcOV_a5Hn1PpAlVG1uVHIT0c1NiosVdb4-1gT6UT0zXfJ4klThSb_FlOuGgPhdHD0sXxttlAbMv5yjdJ4WDYauaK9cCxE2wAUweLQ2sQbO_iIJOhhazzwbwMz2T5W_vXRB_Ui8lPmb1AdCsEsS-WYubC-D7OUWYZW6K0sW8MSfYwqegRJFbzowEIJoAZIvrTWSabpn5A_lV3Lt_6HC9SNkk5VuZzQX64s=&amp;p=1&amp;fvj=1&amp;vjs=3" id="sja1" onclick="setRefineByCookie(['radius']); sjoc('sja1', 1); convCtr('SJ'); rclk(this,jobmap[1],true,1);" onmousedown="sjomd('sja1'); clk('sja1'); rclk(this,jobmap[1],1);" rel="noopener nofollow" target="_blank" title="Data Scientist">
# <b>Data</b> <b>Scientist</b></a>
# <span class="new">new</span></h2>, <h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0
onclick="setRefineByCookie(['radius']); return rclk(this,jobmap[14],true,0);" onmousedown="return rclk(this,jobmap[14],0);" rel="noopener nofollow" target="_blank" title="Data Scientist">
# <b>Data</b> <b>Scientist</b></a>
# </h2>, <h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/company/Competitive-Analytics/jobs/Accounting-Finance-Data-Scientist-170c9b75f9736574?fccid=4162bb76db63f003&amp;vjs=3" id="jl_170c9b75f9736574" onclick="setRefineByCookie(['radius']); return rclk(this,jobmap[15],true,1);" onmousedown="return rclk(this,jobmap[15],1);" rel="noopener nofollow" target="_blank" title="Accounting Finance Data Scientist">
# Accounting Finance <b>Data</b> <b>Scientist</b></a>
# </h2>, <h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0ClvsRMZZYbWkncYKklQZhomgGvtzxN2NDL0Yep_oEtFRBSc398mSurhg85pZ9IK4hwZENIdnfMrd9vgmYaldPQpYZYmqd_RWsMa-UQUHq33lrt1JtH8E7ZxWSo7ImAkgsQHQpZ3y3tmy7gmAY8NN36ukbUMuJZOPf8odOi9ueOllFZaVH93Ap9PLhZA0phz3AFeZWrCyOZCcRSwPpoV_iosMBRj02YUd-41EJXla2th5i6YTJSf5gh7Q0n2poJIxk632q-RD_sVkmpCOTZz3luchSXLFth7RJsgqqFqqohz_YPupw2rBkmtkgKT76G-ADE_nSIf0us8BhoA6NNGxbbbW6ISE2m5vEQh-0eQvDsxRdw3BEDR2jZx2qIIjQ888te-9_bMY2MBUBS9dB8lXQZ&amp;p=16&amp;fvj=0&amp;vjs=3" id="sja16" onclick="setRefineByCookie(['radius']); sjoc('sja16', 0); convCtr('SJ'); rclk(this,jobmap[16],true,0);" onmousedown="sjomd('sja16'); clk('sja16'); rclk(this,jobmap[16],0);" rel="noopener nofollow" target="_blank" title="Senior Data Scientist">
# Senior <b>Data</b> <b>Scientist</b></a>
# <span class="new">new</span></h2>, <h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0ClvsRMZZYbWkncYKklQZhomgGvtzxN2NDL0Yep_oEtFRBSc398mSurhg85pZ9IK4hwZENIdnfMrfT31QlmgQnUNsllJCuzCyoL6Y8z-8PyQo2okYl75ZdJ1F6hsfqRCcpp1Z-R9T2X6kucCAyUQ1kNNld1HMMlL2cjG6jH8a5i2zQGvbiNpeBr8jnbhIwR2a8VMKboRPVDMZq8sUMwAsqwueZLu92Q9EMwBnFMtMHfLQY39kCctfrALkddJeVRDyAs_SG3nYmy2QDZe4_ICQ0DTGIKirKk82_z7Hu747UCtGFK3s0z8SmlOSYCqN5deE1xZ9zhyxhTfss8Ukii0t6GJQDHc5KY0vBUv_GmbZi8TXQ1HvJvEArFay2n70c4bOngS4Tz40Ipug==&amp;p=17&amp;fvj=0&amp;vjs=3" id="sja17" onclick="setRefineByCookie(['radius']); sjoc('sja17', 0); convCtr('SJ'); rclk(this,jobmap[17],true,0);" onmousedown="sjomd('sja17'); clk('sja17'); rclk(this,jobmap[17],0);" rel="noopener nofollow" target="_blank" title="Staff Data Scientist - Analytics">
# Staff <b>Data</b> <b>Scientist</b> - Analytics</a>
# <span class="new">new</span></h2>]

# %%
#result to be Returned as an iterable list
for title in titles:
    job_title = title.get_text()
    print(job_title)
# Out:
# Educational Data Scientist
#
#
#
# Data Scientist
# new
#
#
# Senior Health Data Analyst (Remote / Tableau experience requ...
# new
#
#
# Deep Learning Research Scientist / Engineer (Deep Learning &...
#
#
#
# Staff Data Scientist
# new
#
#
# Senior Data Analyst
#
#
#
# Sr. Principal Data Scientist
#
#
#
# Data Scientist
# new
#
#
# Data Scientist
#
#
#
# Data Scientist
#
#
#
# Data Scientist
#
#
#
# Data Scientist
#
#
#
# Data Scientist
#
#
#
# Data Scientist
# new
#
#
# Data Scientist
#
#
#
# Accounting Finance Data Scientist
#
#
#
# Senior Data Scientist
# new
#
#
# Staff Data Scientist - Analytics
# new

# %%
try:
    dismiss = browser.find_by_xpath('/html/body/div[2]/div/section/div/div[2]')
    more_jobs = browser.find_by_xpath('/html/body/table[2]/tbody/tr/td/table/tbody/tr/td[1]/nav/div/ul/li[6]/a/span')
    no_thanks = browser.find_by_xpath('/html/body/div[3]/div[2]/div[4]/div[3]/div[2]/a')
    dismiss.first.click()
    more_jobs.first.click()
    no_thanks.first.click()
except:
    print("not found")
# Out:
# not found

# %%
#Empty list to append the the result and index 0 is an int 
job_titles = [0]
 
 #loop through the result    
for x in range(1, 2):
    titles = soup.find_all("h2", class_ = "title")
    for title in titles:
        job_titles.append(title.text)
        print('page:', x, '-------------')
        print(title.text)
        browser.find_by_xpath('/html/body/table[2]/tbody/tr/td/table/tbody/tr/td[1]/nav/div/ul/li[6]/a/span/span')
# Out:
# page: 1 -------------
#
#
# Educational Data Scientist
#
# page: 1 -------------
#
#
# Data Scientist
# new
# page: 1 -------------
#
#
# Senior Health Data Analyst (Remote / Tableau experience requ...
# new
# page: 1 -------------
#
#
# Deep Learning Research Scientist / Engineer (Deep Learning &...
#
# page: 1 -------------
#
#
# Staff Data Scientist
# new
# page: 1 -------------
#
#
# Senior Data Analyst
#
# page: 1 -------------
#
#
# Sr. Principal Data Scientist
#
# page: 1 -------------
#
#
# Data Scientist
# new
# page: 1 -------------
#
#
# Data Scientist
#
# page: 1 -------------
#
#
# Data Scientist
#
# page: 1 -------------
#
#
# Data Scientist
#
# page: 1 -------------
#
#
# Data Scientist
#
# page: 1 -------------
#
#
# Data Scientist
#
# page: 1 -------------
#
#
# Data Scientist
# new
# page: 1 -------------
#
#
# Data Scientist
#
# page: 1 -------------
#
#
# Accounting Finance Data Scientist
#
# page: 1 -------------
#
#
# Senior Data Scientist
# new
# page: 1 -------------
#
#
# Staff Data Scientist - Analytics
# new

# %%
#Use replace to print out a clean job title
clean_job_titles = []

#loop through result
for job in job_titles[1:]:
    clean_job_title = job.replace('\n', '')
    clean_job_titles.append(clean_job_title)

# %%
#print clean job titles to check
print(clean_job_titles)
# Out:
# ['Educational Data Scientist', 'Data Scientistnew', 'Senior Health Data Analyst (Remote / Tableau experience requ...new', 'Deep Learning Research Scientist / Engineer (Deep Learning &...', 'Staff Data Scientistnew', 'Senior Data Analyst', 'Sr. Principal Data Scientist', 'Data Scientistnew', 'Data Scientist', 'Data Scientist', 'Data Scientist', 'Data Scientist', 'Data Scientist', 'Data Scientistnew', 'Data Scientist', 'Accounting Finance Data Scientist', 'Senior Data Scientistnew', 'Staff Data Scientist - Analyticsnew']

# %%
#result to return the job locations
locations = soup.find_all("span", class_ = "location accessible-contrast-color-location")
locations
# Out:
# [<span class="location accessible-contrast-color-location">Irvine, CA</span>,
#  <span class="location accessible-contrast-color-location">Los Angeles, CA</span>,
#  <span class="location accessible-contrast-color-location">Irvine, CA</span>,
#  <span class="location accessible-contrast-color-location">Irvine, CA 92618 <span style="font-size: smaller">(East Industrial Complex area)</span></span>,
#  <span class="location accessible-contrast-color-location">Irvine, CA 92617 <span style="font-size: smaller">(Research Park area)</span></span>,
#  <span class="location accessible-contrast-color-location">Irvine, CA 92617 <span style="font-size: smaller">(Research Park area)</span></span>,
#  <span class="location accessible-contrast-color-location">Pasadena, CA 91101 <span style="font-size: smaller">(South area)</span></span>,
#  <span class="location accessible-contrast-color-location">San Diego, CA 92127</span>,
#  <span class="location accessible-contrast-color-location">Newport Beach, CA 92660</span>]

# %%
#Empty list to append the result
job_locations = []


#loop through the returned result
for x in range(1, 2):
    locations = soup.find_all("span", class_ = "location accessible-contrast-color-location")
    for location in locations:
        job_locations.append(location.text)
        print('page:', x, '-------------')
        print(location.text)
        browser.find_by_xpath('/html/body/table[2]/tbody/tr/td/table/tbody/tr/td[1]/div[7]/div[1]/span[1]')
# Out:
# page: 1 -------------
# Irvine, CA
# page: 1 -------------
# Los Angeles, CA
# page: 1 -------------
# Irvine, CA
# page: 1 -------------
# Irvine, CA 92618 (East Industrial Complex area)
# page: 1 -------------
# Irvine, CA 92617 (Research Park area)
# page: 1 -------------
# Irvine, CA 92617 (Research Park area)
# page: 1 -------------
# Pasadena, CA 91101 (South area)
# page: 1 -------------
# San Diego, CA 92127
# page: 1 -------------
# Newport Beach, CA 92660

# %%
#print job locations
print(job_locations)
browser.quit()
# Out:
# ['Irvine, CA', 'Los Angeles, CA', 'Irvine, CA', 'Irvine, CA 92618 (East Industrial Complex area)', 'Irvine, CA 92617 (Research Park area)', 'Irvine, CA 92617 (Research Park area)', 'Pasadena, CA 91101 (South area)', 'San Diego, CA 92127', 'Newport Beach, CA 92660']

# %%
#zip both result into a list
new_list = list(zip(clean_job_titles, job_locations))

# %%
#print new_list that has both the job_titiles and locations
print(new_list)
# Out:
# [('Educational Data Scientist', 'Irvine, CA'), ('Data Scientistnew', 'Los Angeles, CA'), ('Senior Health Data Analyst (Remote / Tableau experience requ...new', 'Irvine, CA'), ('Deep Learning Research Scientist / Engineer (Deep Learning &...', 'Irvine, CA 92618 (East Industrial Complex area)'), ('Staff Data Scientistnew', 'Irvine, CA 92617 (Research Park area)'), ('Senior Data Analyst', 'Irvine, CA 92617 (Research Park area)'), ('Sr. Principal Data Scientist', 'Pasadena, CA 91101 (South area)'), ('Data Scientistnew', 'San Diego, CA 92127'), ('Data Scientist', 'Newport Beach, CA 92660')]

# %%
#append list into a python dictionary
updated_list = dict(new_list)
updated_list
# Out:
# {'Educational Data Scientist': 'Irvine, CA',
#  'Data Scientistnew': 'San Diego, CA 92127',
#  'Senior Health Data Analyst (Remote / Tableau experience requ...new': 'Irvine, CA',
#  'Deep Learning Research Scientist / Engineer (Deep Learning &...': 'Irvine, CA 92618 (East Industrial Complex area)',
#  'Staff Data Scientistnew': 'Irvine, CA 92617 (Research Park area)',
#  'Senior Data Analyst': 'Irvine, CA 92617 (Research Park area)',
#  'Sr. Principal Data Scientist': 'Pasadena, CA 91101 (South area)',
#  'Data Scientist': 'Newport Beach, CA 92660'}

# %%
#append colums keys
New_job_location_df = pd.DataFrame(new_list, columns=['Job_Title', 'Location'])
New_job_location_df
# Out:
#                                            Job_Title  \
# 0                         Educational Data Scientist
# 1                                  Data Scientistnew
# 2  Senior Health Data Analyst (Remote / Tableau e...
# 3  Deep Learning Research Scientist / Engineer (D...
# 4                            Staff Data Scientistnew
# 5                                Senior Data Analyst
# 6                       Sr. Principal Data Scientist
# 7                                  Data Scientistnew
# 8                                     Data Scientist
#
#                                           Location
# 0                                       Irvine, CA
# 1                                  Los Angeles, CA
# 2                                       Irvine, CA
# 3  Irvine, CA 92618 (East Industrial Complex area)
# 4            Irvine, CA 92617 (Research Park area)
# 5            Irvine, CA 92617 (Research Park area)
# 6                  Pasadena, CA 91101 (South area)
# 7                              San Diego, CA 92127
# 8                          Newport Beach, CA 92660

# %%
New_job_location_df['City'] = New_job_location_df['Location'].str.split(',').str[0]

# %%
New_job_location_df['Lat'] = ''
New_job_location_df['Lng'] = ''

# %%
New_job_location_df
# Out:
#                                            Job_Title  \
# 0                         Educational Data Scientist
# 1                                  Data Scientistnew
# 2  Senior Health Data Analyst (Remote / Tableau e...
# 3  Deep Learning Research Scientist / Engineer (D...
# 4                            Staff Data Scientistnew
# 5                                Senior Data Analyst
# 6                       Sr. Principal Data Scientist
# 7                                  Data Scientistnew
# 8                                     Data Scientist
#
#                                           Location           City Lat Lng
# 0                                       Irvine, CA         Irvine
# 1                                  Los Angeles, CA    Los Angeles
# 2                                       Irvine, CA         Irvine
# 3  Irvine, CA 92618 (East Industrial Complex area)         Irvine
# 4            Irvine, CA 92617 (Research Park area)         Irvine
# 5            Irvine, CA 92617 (Research Park area)         Irvine
# 6                  Pasadena, CA 91101 (South area)       Pasadena
# 7                              San Diego, CA 92127      San Diego
# 8                          Newport Beach, CA 92660  Newport Beach

# %%
for index, row in New_job_location_df.iterrows():
    city = row['City']
    base_url = "https://api.mapbox.com/geocoding/v5/mapbox.places/"
    response = requests.get(f'{base_url}{city}.json?access_token={api_key}').json()
    
    try:
        print(f'Retrieving rating data for {city}')
        New_job_location_df.loc[index, 'Lat'] = response['features'][0]['geometry']['coordinates'][1]
        New_job_location_df.loc[index, 'Lng'] = response['features'][0]['geometry']['coordinates'][0]
    except(KeyError, IndexError):
        print('Missing data')
# Out:
# Retrieving rating data for Irvine
# Retrieving rating data for Los Angeles
# Retrieving rating data for Irvine
# Retrieving rating data for Irvine
# Retrieving rating data for Irvine
# Retrieving rating data for Irvine
# Retrieving rating data for Pasadena
# Retrieving rating data for San Diego
# Retrieving rating data for Newport Beach

# %%
New_job_location_df
# Out:
#                                            Job_Title  \
# 0                         Educational Data Scientist
# 1                                  Data Scientistnew
# 2  Senior Health Data Analyst (Remote / Tableau e...
# 3  Deep Learning Research Scientist / Engineer (D...
# 4                            Staff Data Scientistnew
# 5                                Senior Data Analyst
# 6                       Sr. Principal Data Scientist
# 7                                  Data Scientistnew
# 8                                     Data Scientist
#
#                                           Location           City      Lat  \
# 0                                       Irvine, CA         Irvine  33.6857
# 1                                  Los Angeles, CA    Los Angeles  34.0544
# 2                                       Irvine, CA         Irvine  33.6857
# 3  Irvine, CA 92618 (East Industrial Complex area)         Irvine  33.6857
# 4            Irvine, CA 92617 (Research Park area)         Irvine  33.6857
# 5            Irvine, CA 92617 (Research Park area)         Irvine  33.6857
# 6                  Pasadena, CA 91101 (South area)       Pasadena  29.6911
# 7                              San Diego, CA 92127      San Diego  32.7174
# 8                          Newport Beach, CA 92660  Newport Beach   33.617
#
#        Lng
# 0 -117.826
# 1 -118.244
# 2 -117.826
# 3 -117.826
# 4 -117.826
# 5 -117.826
# 6 -95.2091
# 7 -117.163
# 8 -117.929

# %%
# test_city = 'Irvine'
# base_url = "https://api.mapbox.com/geocoding/v5/mapbox.places/"
# search = base_url + test_city + '.json?access_token=' + api_key

# response = requests.get(search).json()
# response


# lat = response['features'][0]['geometry']['coordinates'][1]
# lng = response['features'][0]['geometry']['coordinates'][0]
# print(lat)
# print(lng)

# %%
New_job_location_df['job_type'] = 'Data Scientist'

# %%
New_job_location_df
# Out:
#                                            Job_Title  \
# 0                         Educational Data Scientist
# 1                                  Data Scientistnew
# 2  Senior Health Data Analyst (Remote / Tableau e...
# 3  Deep Learning Research Scientist / Engineer (D...
# 4                            Staff Data Scientistnew
# 5                                Senior Data Analyst
# 6                       Sr. Principal Data Scientist
# 7                                  Data Scientistnew
# 8                                     Data Scientist
#
#                                           Location           City      Lat  \
# 0                                       Irvine, CA         Irvine  33.6857
# 1                                  Los Angeles, CA    Los Angeles  34.0544
# 2                                       Irvine, CA         Irvine  33.6857
# 3  Irvine, CA 92618 (East Industrial Complex area)         Irvine  33.6857
# 4            Irvine, CA 92617 (Research Park area)         Irvine  33.6857
# 5            Irvine, CA 92617 (Research Park area)         Irvine  33.6857
# 6                  Pasadena, CA 91101 (South area)       Pasadena  29.6911
# 7                              San Diego, CA 92127      San Diego  32.7174
# 8                          Newport Beach, CA 92660  Newport Beach   33.617
#
#        Lng        job_type
# 0 -117.826  Data Scientist
# 1 -118.244  Data Scientist
# 2 -117.826  Data Scientist
# 3 -117.826  Data Scientist
# 4 -117.826  Data Scientist
# 5 -117.826  Data Scientist
# 6 -95.2091  Data Scientist
# 7 -117.163  Data Scientist
# 8 -117.929  Data Scientist

# %%
#Define database and collection
#Database = Indeed_db
#Collections = Data_jobs
client.Indeed_db.Data_jobs.insert_many(New_job_location_df.to_dict('records'))

# %%
#Done
