# %%
#import Dependencies
from splinter import Browser
from bs4 import BeautifulSoup
import pandas as pd
import pymongo 
import requests
from config import api_key

# %%
#executable path for window users
# executable_path = {'executable_path': 'chromedriver.exe'}
# browser = Browser('chrome', **executable_path, headless=False)

# %%
#Initialize pymongo to work with MongoDBs
#CONNECT MONGO DB
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
#Executable path for Mac Users
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
#url of page to be scrapped from indeed 
url = 'https://www.indeed.com/jobs?q=Front+End+Developer&l=Irvine%2C+CA&radius=100'
browser.visit(url)

# %%
#BeautifulSoup Parser
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
#result to return the job title
titles = soup.find_all("h2", class_ = "title")
print(titles)
#title[1].get_text()
# Out:
# [<h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0DOnIuMyiGYhvBYNXg_sIChdZciTQQ_BJ3O4ZgSerV_skWWWUTnMc20zMa8tBbumV2uN6cQxpNalFtyVg0X1a1M840Rzg7sb185oMEijVSf2rgQaF53EW4Ea92tcEx7TEpCh_w5sG9KzikSvi9xePapjIUY4YJ2oM2vrwYpCjs8Wdje_Kd41C3OtpPiVsXFeTZ6PqqhdMgmt74MGPSKngzu5T0szImTRR-97ze_kpJQuV9TQO6bMcRYXhGsz0mwAH-eJXrO5KU7fTrJpdow6wVg8GYHH59gF6KAOV5dHlNWpERVlWRUtu9ct42oeCv0LN_3h_NU0EchwAXWE54G2ktlMmISkPsLLmyuqbOGQI4giuRgCnuhilwdKEx_4UrUvh4_uXRW-MCaM2I7phPu7Qf-JxhC2j6htfYIpJGtFody5ndr9O5PbPwrdj6MNd66c4FAK0NVKir61h5YpCMH8lnINnOJUmb0svU=&amp;p=0&amp;fvj=1&amp;vjs=3" id="sja0" onclick="setRefineByCookie(['radius']); sjoc('sja0', 0); convCtr('SJ'); rclk(this,jobmap[0],true,0);" onmousedown="sjomd('sja0'); clk('sja0'); rclk(this,jobmap[0],0);" rel="noopener nofollow" target="_blank" title="Front End Developer">
# <b>Front</b> <b>End</b> <b>Developer</b></a>
# </h2>, <h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0C2BFb7Ub2YUp4strrym9V3pWtjyRKtgHKt_kMzkewmGGJEved23y_kY-GSZp2akmM_B33NOoM3gSm-9Lc3PtKkC7N6FuwW-TegL7BsvikExrsvUn01uhUaA7YnC06HYPfwVOrDTPEBQsE_KxJ8lIRBqLda9DBbZwyAi7RZPAvBrjf2CuFpFAqCwZvoD8Dds-x8ZGiothRXlKKYaDbfKsQKUkMN-vGa02sCOJZw4Xx-bQQSK8PLBa5xfRiayChTDZMjCtChsuM2m1rXKx5NETzcV8oq41Djc4swb2P3yRnhF7PAQMLxeowvxW08PeK_7Z3OyapTS3Wabt4dKeYM3fEa5_YjbF-UUvmCi-oARYZ105g6P8wW8KxpK8hPlzH7QDxi3cLHV3qC_linZExMg6Z4n4FsZYtharlZX5GF2orxs33JfOEF2Syrb6olQgCJVn6K3_KwJwPMRcgsMW6YOc-wfkpFGgx_JHU=&amp;p=1&amp;fvj=1&amp;vjs=3" id="sja1" onclick="setRefineByCookie(['radius']); sjoc('sja1', 1); convCtr('SJ'); rclk(this,jobmap[1],true,1);" onmousedown="sjomd('sja1'); clk('sja1'); rclk(this,jobmap[1],1);" rel="noopener nofollow" target="_blank" title="Sr. Front End Developer">
# Sr. <b>Front</b> <b>End</b> <b>Developer</b></a>
# <span class="new">new</span></h2>, <h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN
b>Developer</b></a>
# </h2>, <h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=65caf470dadb52cb&amp;fccid=d105a9617f166971&amp;vjs=3" id="jl_65caf470dadb52cb" onclick="setRefineByCookie(['radius']); return rclk(this,jobmap[11],true,1);" onmousedown="return rclk(this,jobmap[11],1);" rel="noopener nofollow" target="_blank" title="Front-End Developer">
# <b>Front</b>-<b>End</b> <b>Developer</b></a>
# </h2>, <h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/company/Building-Safety-Solutions,-Inc./jobs/Front-End-Developer-4012b596b9d93b46?fccid=9a0a06794ecc71d1&amp;vjs=3" id="jl_4012b596b9d93b46" onclick="setRefineByCookie(['radius']); return rclk(this,jobmap[12],true,0);" onmousedown="return rclk(this,jobmap[12],0);" rel="noopener nofollow" target="_blank" title="Front End Developer">
# <b>Front</b> <b>End</b> <b>Developer</b></a>
# </h2>, <h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=257100d2ff0ba4df&amp;fccid=2cfd7ba40e131adb&amp;vjs=3" id="jl_257100d2ff0ba4df" onclick="setRefineByCookie(['radius']); return rclk(this,jobmap[13],true,0);" onmousedown="return rclk(this,jobmap[13],0);" rel="noopener nofollow" target="_blank" title="Front End Developer">
# <b>Front</b> <b>End</b> <b>Developer</b></a>
# </h2>, <h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/company/HIRECLOUT/jobs/Front-End-Developer-7ecfb5e15dc52fa5?fccid=20b7fd589143f62a&amp;vjs=3" id="jl_7ecfb5e15dc52fa5" onclick="setRefineByCookie(['radius']); return rclk(this,jobmap[14],true,1);" onmousedown="return rclk(this,jobmap[14],1);" rel="noopener nofollow" target="_blank" title="Front End Developer">
# <b>Front</b> <b>End</b> <b>Developer</b></a>
# <span class="new">new</span></h2>]

# %%
#result to be Returned as an iterable list
for title in titles:
    job_title = title.get_text()
    print(job_title)
# Out:
# Front End Developer
#
#
#
# Sr. Front End Developer
# new
#
#
# Front-End Developer
#
#
#
# Front End Developer
#
#
#
# Software Engineer 2, Front End
# new
#
#
# Staff Software Engineer, Front End
# new
#
#
# Junior Front-end Web Developer
# new
#
#
# Front End Developer
# new
#
#
# Front End Web Developer, Angular
# new
#
#
# HTML Developer | CSS Mobile First | Front End
#
#
#
# Junior Front-End Web Developer
#
#
#
# Front-End Developer
#
#
#
# Front End Developer
#
#
#
# Front End Developer
#
#
#
# Front End Developer
# new

# %%
try:
    dismiss = browser.find_by_xpath('/html/body/div[2]/div/section/div/div[2]')
    more_jobs = browser.find_by_xpath('/html/body/table[2]/tbody/tr/td/table/tbody/tr/td[1]/nav/div/ul/li[6]/a/span')
    no_thanks = browser.find_by_xpath('/html/body/div[3]/div[2]/div[4]/div[3]/div[2]/a')
    dismiss.first.click()
    more_jobs.first.click()
    no_thanks.first.click()
except:
    print("not found")
# Out:
# not found

# %%
#Empty list to append the the result and index 0 is an int 
job_titles = [0]

 #loop through the result
for x in range(1, 2):
    titles = soup.find_all("h2", class_ = "title")
    for title in titles:
        job_titles.append(title.text)
        print('page:', x, '-------------')
        print(title.text)
        browser.find_by_xpath('/html/body/table[2]/tbody/tr/td/table/tbody/tr/td[1]/nav/div/ul/li[6]/a/span/span')
# Out:
# page: 1 -------------
#
#
# Front End Developer
#
# page: 1 -------------
#
#
# Sr. Front End Developer
# new
# page: 1 -------------
#
#
# Front-End Developer
#
# page: 1 -------------
#
#
# Front End Developer
#
# page: 1 -------------
#
#
# Software Engineer 2, Front End
# new
# page: 1 -------------
#
#
# Staff Software Engineer, Front End
# new
# page: 1 -------------
#
#
# Junior Front-end Web Developer
# new
# page: 1 -------------
#
#
# Front End Developer
# new
# page: 1 -------------
#
#
# Front End Web Developer, Angular
# new
# page: 1 -------------
#
#
# HTML Developer | CSS Mobile First | Front End
#
# page: 1 -------------
#
#
# Junior Front-End Web Developer
#
# page: 1 -------------
#
#
# Front-End Developer
#
# page: 1 -------------
#
#
# Front End Developer
#
# page: 1 -------------
#
#
# Front End Developer
#
# page: 1 -------------
#
#
# Front End Developer
# new

# %%
#Use replace to print out a clean job title
clean_job_titles = []

#loop through result
for job in job_titles[1:]:
    clean_job_title = job.replace('\n', '')
    clean_job_titles.append(clean_job_title)

# %%
#print clean job titles to check
print(clean_job_titles)
# Out:
# ['Front End Developer', 'Sr. Front End Developernew', 'Front-End Developer', 'Front End Developer', 'Software Engineer 2, Front Endnew', 'Staff Software Engineer, Front Endnew', 'Junior Front-end Web Developernew', 'Front End Developernew', 'Front End Web Developer, Angularnew', 'HTML Developer | CSS Mobile First | Front End', 'Junior Front-End Web Developer', 'Front-End Developer', 'Front End Developer', 'Front End Developer', 'Front End Developernew']

# %%
#result to return the job locations
locations = soup.find_all("span", class_ = "location accessible-contrast-color-location")
locations
# Out:
# [<span class="location accessible-contrast-color-location">Newport Beach, CA 92660</span>,
#  <span class="location accessible-contrast-color-location">Orange, CA 92867</span>,
#  <span class="location accessible-contrast-color-location">Santa Ana, CA 92705</span>,
#  <span class="location accessible-contrast-color-location">Lake Forest, CA 92630</span>,
#  <span class="location accessible-contrast-color-location">Irvine, CA 92614 <span style="font-size: smaller">(Business District area)</span></span>,
#  <span class="location accessible-contrast-color-location">Newport Beach, CA 92660</span>,
#  <span class="location accessible-contrast-color-location">Pasadena, CA 91101</span>,
#  <span class="location accessible-contrast-color-location">Santa Ana, CA 92707</span>,
#  <span class="location accessible-contrast-color-location">Los Angeles, CA 90089 <span style="font-size: smaller">(University Park area)</span></span>]

# %%
#Empty list to append the result
job_locations = []

#loop through the returned result
for x in range(1, 2):
    locations = soup.find_all("span", class_ = "location accessible-contrast-color-location")
    for location in locations:
        job_locations.append(location.text)
        print('page:', x, '-------------')
        print(location.text)
        browser.find_by_xpath('/html/body/table[2]/tbody/tr/td/table/tbody/tr/td[1]/div[7]/div[1]/span[1]')
# Out:
# page: 1 -------------
# Newport Beach, CA 92660
# page: 1 -------------
# Orange, CA 92867
# page: 1 -------------
# Santa Ana, CA 92705
# page: 1 -------------
# Lake Forest, CA 92630
# page: 1 -------------
# Irvine, CA 92614 (Business District area)
# page: 1 -------------
# Newport Beach, CA 92660
# page: 1 -------------
# Pasadena, CA 91101
# page: 1 -------------
# Santa Ana, CA 92707
# page: 1 -------------
# Los Angeles, CA 90089 (University Park area)

# %%
#print job locations
print(job_locations)
# Out:
# ['Newport Beach, CA 92660', 'Orange, CA 92867', 'Santa Ana, CA 92705', 'Lake Forest, CA 92630', 'Irvine, CA 92614 (Business District area)', 'Newport Beach, CA 92660', 'Pasadena, CA 91101', 'Santa Ana, CA 92707', 'Los Angeles, CA 90089 (University Park area)']

# %%
#zip both result into a list
new_list = list(zip(clean_job_titles, job_locations))

# %%
#print new_list that has both the job_titiles and locations
print(new_list)
# Out:
# [('Front End Developer', 'Newport Beach, CA 92660'), ('Sr. Front End Developernew', 'Orange, CA 92867'), ('Front-End Developer', 'Santa Ana, CA 92705'), ('Front End Developer', 'Lake Forest, CA 92630'), ('Software Engineer 2, Front Endnew', 'Irvine, CA 92614 (Business District area)'), ('Staff Software Engineer, Front Endnew', 'Newport Beach, CA 92660'), ('Junior Front-end Web Developernew', 'Pasadena, CA 91101'), ('Front End Developernew', 'Santa Ana, CA 92707'), ('Front End Web Developer, Angularnew', 'Los Angeles, CA 90089 (University Park area)')]

# %%
#append list into a python dictionary
updated_list = dict(new_list)
updated_list
# Out:
# {'Front End Developer': 'Lake Forest, CA 92630',
#  'Sr. Front End Developernew': 'Orange, CA 92867',
#  'Front-End Developer': 'Santa Ana, CA 92705',
#  'Software Engineer 2, Front Endnew': 'Irvine, CA 92614 (Business District area)',
#  'Staff Software Engineer, Front Endnew': 'Newport Beach, CA 92660',
#  'Junior Front-end Web Developernew': 'Pasadena, CA 91101',
#  'Front End Developernew': 'Santa Ana, CA 92707',
#  'Front End Web Developer, Angularnew': 'Los Angeles, CA 90089 (University Park area)'}

# %%
#append colums keys
New_job_location_df = pd.DataFrame(new_list, columns=['Job_Title', 'Location'])
New_job_location_df
# Out:
#                                Job_Title  \
# 0                    Front End Developer
# 1             Sr. Front End Developernew
# 2                    Front-End Developer
# 3                    Front End Developer
# 4      Software Engineer 2, Front Endnew
# 5  Staff Software Engineer, Front Endnew
# 6      Junior Front-end Web Developernew
# 7                 Front End Developernew
# 8    Front End Web Developer, Angularnew
#
#                                        Location
# 0                       Newport Beach, CA 92660
# 1                              Orange, CA 92867
# 2                           Santa Ana, CA 92705
# 3                         Lake Forest, CA 92630
# 4     Irvine, CA 92614 (Business District area)
# 5                       Newport Beach, CA 92660
# 6                            Pasadena, CA 91101
# 7                           Santa Ana, CA 92707
# 8  Los Angeles, CA 90089 (University Park area)

# %%
New_job_location_df['City'] = New_job_location_df['Location'].str.split(',').str[0]

# %%
New_job_location_df['Lat'] = ''
New_job_location_df['Lng'] = ''

# %%
New_job_location_df
# Out:
#                                Job_Title  \
# 0                    Front End Developer
# 1             Sr. Front End Developernew
# 2                    Front-End Developer
# 3                    Front End Developer
# 4      Software Engineer 2, Front Endnew
# 5  Staff Software Engineer, Front Endnew
# 6      Junior Front-end Web Developernew
# 7                 Front End Developernew
# 8    Front End Web Developer, Angularnew
#
#                                        Location           City Lat Lng
# 0                       Newport Beach, CA 92660  Newport Beach
# 1                              Orange, CA 92867         Orange
# 2                           Santa Ana, CA 92705      Santa Ana
# 3                         Lake Forest, CA 92630    Lake Forest
# 4     Irvine, CA 92614 (Business District area)         Irvine
# 5                       Newport Beach, CA 92660  Newport Beach
# 6                            Pasadena, CA 91101       Pasadena
# 7                           Santa Ana, CA 92707      Santa Ana
# 8  Los Angeles, CA 90089 (University Park area)    Los Angeles

# %%
for index, row in New_job_location_df.iterrows():
    city = row['City']
    base_url = "https://api.mapbox.com/geocoding/v5/mapbox.places/"
    response = requests.get(f'{base_url}{city}.json?access_token={api_key}').json()
    
    try:
        print(f'Retrieving rating data for {city}')
        New_job_location_df.loc[index, 'Lat'] = response['features'][0]['geometry']['coordinates'][1]
        New_job_location_df.loc[index, 'Lng'] = response['features'][0]['geometry']['coordinates'][0]
    except(KeyError, IndexError):
        print('Missing data')
# Out:
# Retrieving rating data for Newport Beach
# Retrieving rating data for Orange
# Retrieving rating data for Santa Ana
# Retrieving rating data for Lake Forest
# Retrieving rating data for Irvine
# Retrieving rating data for Newport Beach
# Retrieving rating data for Pasadena
# Retrieving rating data for Santa Ana
# Retrieving rating data for Los Angeles

# %%
New_job_location_df
# Out:
#                                Job_Title  \
# 0                    Front End Developer
# 1             Sr. Front End Developernew
# 2                    Front-End Developer
# 3                    Front End Developer
# 4      Software Engineer 2, Front Endnew
# 5  Staff Software Engineer, Front Endnew
# 6      Junior Front-end Web Developernew
# 7                 Front End Developernew
# 8    Front End Web Developer, Angularnew
#
#                                        Location           City      Lat  \
# 0                       Newport Beach, CA 92660  Newport Beach   33.617
# 1                              Orange, CA 92867         Orange  33.7873
# 2                           Santa Ana, CA 92705      Santa Ana  33.7495
# 3                         Lake Forest, CA 92630    Lake Forest   33.647
# 4     Irvine, CA 92614 (Business District area)         Irvine  33.6857
# 5                       Newport Beach, CA 92660  Newport Beach   33.617
# 6                            Pasadena, CA 91101       Pasadena  29.6911
# 7                           Santa Ana, CA 92707      Santa Ana  33.7495
# 8  Los Angeles, CA 90089 (University Park area)    Los Angeles  34.0544
#
#        Lng
# 0 -117.929
# 1  -117.85
# 2 -117.873
# 3 -117.689
# 4 -117.826
# 5 -117.929
# 6 -95.2091
# 7 -117.873
# 8 -118.244

# %%
# test_city = 'Irvine'
# base_url = "https://api.mapbox.com/geocoding/v5/mapbox.places/"
# search = base_url + test_city + '.json?access_token=' + api_key

# response = requests.get(search).json()
# response


# lat = response['features'][0]['geometry']['coordinates'][1]
# lng = response['features'][0]['geometry']['coordinates'][0]
# print(lat)
# print(lng)

# %%
New_job_location_df['job_type'] = 'Front-End Developer'

# %%
New_job_location_df
# Out:
#                                Job_Title  \
# 0                    Front End Developer
# 1             Sr. Front End Developernew
# 2                    Front-End Developer
# 3                    Front End Developer
# 4      Software Engineer 2, Front Endnew
# 5  Staff Software Engineer, Front Endnew
# 6      Junior Front-end Web Developernew
# 7                 Front End Developernew
# 8    Front End Web Developer, Angularnew
#
#                                        Location           City      Lat  \
# 0                       Newport Beach, CA 92660  Newport Beach   33.617
# 1                              Orange, CA 92867         Orange  33.7873
# 2                           Santa Ana, CA 92705      Santa Ana  33.7495
# 3                         Lake Forest, CA 92630    Lake Forest   33.647
# 4     Irvine, CA 92614 (Business District area)         Irvine  33.6857
# 5                       Newport Beach, CA 92660  Newport Beach   33.617
# 6                            Pasadena, CA 91101       Pasadena  29.6911
# 7                           Santa Ana, CA 92707      Santa Ana  33.7495
# 8  Los Angeles, CA 90089 (University Park area)    Los Angeles  34.0544
#
#        Lng             job_type
# 0 -117.929  Front-End Developer
# 1  -117.85  Front-End Developer
# 2 -117.873  Front-End Developer
# 3 -117.689  Front-End Developer
# 4 -117.826  Front-End Developer
# 5 -117.929  Front-End Developer
# 6 -95.2091  Front-End Developer
# 7 -117.873  Front-End Developer
# 8 -118.244  Front-End Developer

# %%
#Define database and collection
#Database = Indeed_db
#Collections = FrontEnd_jobs
client.Indeed_db.Data_jobs.insert_many(New_job_location_df.to_dict('records'))

# %%
#Done
